# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("C:\\Users\\dices\\Downloads\\Compressed\\archive_3\\Student Stress Factors.csv")
df
# Out:
#               Timestamp  Kindly Rate your Sleep Quality 😴  \
# 0   27/10/2023 21:54:15                                 3
# 1   28/10/2023 12:24:40                                 4
# 2   28/10/2023 12:24:51                                 2
# 3   28/10/2023 12:26:11                                 3
# 4   28/10/2023 12:26:45                                 2
# 5   28/10/2023 12:31:02                                 3
# 6   28/10/2023 12:34:45                                 3
# 7   28/10/2023 12:35:43                                 4
# 8   28/10/2023 12:36:07                                 2
# 9   28/10/2023 12:36:20                                 1
# 10  28/10/2023 12:37:22                                 2
# 11  28/10/2023 12:38:40                                 3
# 12  28/10/2023 12:39:43                                 2
# 13  28/10/2023 12:40:50                                 4
# 14  28/10/2023 12:41:12                                 4
# ...

# %%
# Convert the 'Timestamp' column to datetime format
df['Timestamp'] = pd.to_datetime(df['Timestamp'], dayfirst=True)
df
# Out:
#              Timestamp  Kindly Rate your Sleep Quality 😴  \
# 0  2023-10-27 21:54:15                                 3
# 1  2023-10-28 12:24:40                                 4
# 2  2023-10-28 12:24:51                                 2
# 3  2023-10-28 12:26:11                                 3
# 4  2023-10-28 12:26:45                                 2
# 5  2023-10-28 12:31:02                                 3
# 6  2023-10-28 12:34:45                                 3
# 7  2023-10-28 12:35:43                                 4
# 8  2023-10-28 12:36:07                                 2
# 9  2023-10-28 12:36:20                                 1
# 10 2023-10-28 12:37:22                                 2
# 11 2023-10-28 12:38:40                                 3
# 12 2023-10-28 12:39:43                                 2
# 13 2023-10-28 12:40:50                                 4
# 14 2023-10-28 12:41:12                                 4
# ...

# %%
df_r=df.rename(columns={"Kindly Rate your Sleep Quality 😴":"Sleep Quality",
                   "How many times a week do you suffer headaches 🤕?":"Headaches",
                  "How would you rate you academic performance 👩‍🎓?":"Performance",
                  "how would you rate your study load?":"Study Load",
                  "How many times a week you practice extracurricular activities 🎾?":"Activities",
                  "How would you rate your stress levels?":"Stress Levels"})
df_r
# Out:
#              Timestamp  Sleep Quality  Headaches  Performance  Study Load  \
# 0  2023-10-27 21:54:15              3          1            3           4
# 1  2023-10-28 12:24:40              4          1            2           3
# 2  2023-10-28 12:24:51              2          1            2           1
# 3  2023-10-28 12:26:11              3          2            3           2
# 4  2023-10-28 12:26:45              2          3            1           5
# 5  2023-10-28 12:31:02              3          1            3           2
# 6  2023-10-28 12:34:45              3          5            1           4
# 7  2023-10-28 12:35:43              4          3            1           4
# 8  2023-10-28 12:36:07              2          1            4           4
# 9  2023-10-28 12:36:20              1          2            3           2
# 10 2023-10-28 12:37:22              2          3            5           5
# 11 2023-10-28 12:38:40              3          1            5           1
# ...

# %%
 df_r.describe()
# Out:
#        Sleep Quality  Headaches  Performance  Study Load  Activities  \
# count      53.000000  53.000000    53.000000   53.000000   53.000000
# mean        3.150943   1.981132     3.226415    2.811321    2.886792
# std         1.199298   1.263246     1.154281    1.428509    1.449939
# min         1.000000   1.000000     1.000000    1.000000    1.000000
# 25%         2.000000   1.000000     3.000000    2.000000    2.000000
# 50%         3.000000   1.000000     3.000000    2.000000    3.000000
# 75%         4.000000   3.000000     4.000000    4.000000    4.000000
# max         5.000000   5.000000     5.000000    5.000000    5.000000
#
#        Stress Levels
# count      53.000000
# mean        2.792453
# std         1.377826
# min         1.000000
# 25%         2.000000
# 50%         3.000000
# 75%         4.000000
# max         5.000000

# %%
sns.set(style='whitegrid')
plt.figure(figsize=(12, 6))

for i, column in enumerate(df_r.columns[1:]):
    plt.subplot(2, 3, i + 1)
    sns.histplot(df_r[column], kde=True)
    plt.ylabel('Frequency')
    plt.title(f'Distribution of {column}')

plt.tight_layout()
plt.show()

# %%
corr_matrix = df_r.corr()
sns.heatmap(corr_matrix, annot=True, cmap='Blues')
# Out:
# <AxesSubplot:>

# %%
variables_to_plot = df_r.columns[1:-1]
sns.set(style='whitegrid')
plt.figure(figsize=(12, 6))

for i, column in enumerate(variables_to_plot):
    plt.subplot(2, 3, i + 1)
    sns.barplot(x=column, y='Stress Levels', data=df_r)
    plt.title(f'{column} vs Stress Levels')

plt.tight_layout()
plt.show()

# %%
# Crosstab analysis between Sleep Quality and Stress Level
crosstab_result = pd.crosstab(df_r['Sleep Quality'], df_r['Stress Levels'])

# Display the crosstab result
print("Crosstab Result:")
print(crosstab_result)
# Out:
# Crosstab Result:
# Stress Levels  1  2  3  4  5
# Sleep Quality
# 1              2  2  0  0  0
# 2              1  3  4  5  0
# 3              5  2  7  1  1
# 4              2  5  0  2  2
# 5              2  0  1  1  5

# %%
sns.heatmap(crosstab_result, annot=True, fmt='d', cmap='YlGnBu', cbar=True)
plt.xlabel('Stress Levels')
plt.ylabel('Sleep Quality')
plt.title('Crosstab Analysis: Sleep Quality vs Stress Levels')
plt.show()
